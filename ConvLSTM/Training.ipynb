# %% [markdown]
# ### Download Data

# %%
! wget -q https://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
FOLDERNAME = 'CS_231n_Project/ConvLSTM'
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# /content/drive/My Drive/CS_231n_Project/ConvLSTM

# %% [markdown]
# ### Import Dependencies

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.optim import Adam
from Seq2Seq import Seq2Seq
from torch.utils.data import DataLoader

import io
import imageio
from ipywidgets import widgets, HBox

# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# ### Import Data and Create Dataloaders

# %%
# Load Data as Numpy Array
# (num_videos, T, H, W)
MovingMNIST = np.load('mnist_test_seq.npy').transpose(1, 0, 2, 3)

# Shuffle Data
np.random.shuffle(MovingMNIST)

# Train, Test, Validation splits
train_data = MovingMNIST[:8000]         
val_data = MovingMNIST[8000:9000]       
test_data = MovingMNIST[9000:10000]     

def collate(batch):

    # Add channel dim, scale pixels between 0 and 1, send to GPU
    batch = torch.tensor(batch).unsqueeze(1)     
    batch = batch / 255.0                        
    batch = batch.to(device)                     

    # Randomly pick 10 frames as input, 11th frame is target
    rand = np.random.randint(10,20)                     
    return batch[:,:,rand-10:rand], batch[:,:,rand]     


# Training Data Loader
train_loader = DataLoader(train_data, shuffle=True, 
                        batch_size=16, collate_fn=collate)

# Validation Data Loader
val_loader = DataLoader(val_data, shuffle=True, 
                        batch_size=16, collate_fn=collate)

# %%
MovingMNIST.shape
# Out:
# (10000, 20, 64, 64)

# %% [markdown]
# ### Visualize Data

# %%
# Get a batch
input, _ = next(iter(val_loader))

# Reverse process before displaying
input = input.cpu().numpy() * 255.0     

for video in input.squeeze(1)[:3]:          # Loop over videos
    print(video.shape)
    with io.BytesIO() as gif:
        imageio.mimsave(gif,video.astype(np.uint8),"GIF",fps=5)
        display(HBox([widgets.Image(value=gif.getvalue())]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
#   app.launch_new_instance()
# (10, 64, 64)
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xfb\xfb\xfb\xfa\…
# (10, 64, 64)
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# (10, 64, 64)
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…

# %% [markdown]
# ### Instantiate Model, Optimizer and Loss

# %%
# The input video frames are grayscale, thus single channel
model = Seq2Seq(num_channels=1, num_kernels=64, 
kernel_size=(3, 3), padding=(1, 1), activation="relu", 
frame_size=(64, 64), num_layers=3).to(device)

optim = Adam(model.parameters(), lr=1e-4)

# Binary Cross Entropy, target pixel values either 0 or 1
criterion = nn.BCELoss(reduction='sum')

# %% [markdown]
# ### Train for about 20 epochs

# %%
num_epochs = 1

for epoch in range(1, num_epochs+1):
    
    train_loss = 0                                                 
    model.train()                                                  
    for batch_num, (input, target) in enumerate(train_loader, 1):  

        print(input.shape)
        output = model(input)                                     
        loss = criterion(output.flatten(), target.flatten())       
        loss.backward()                                            
        optim.step()                                               
        optim.zero_grad()                                           
        train_loss += loss.item()                                 
    train_loss /= len(train_loader.dataset)                       

    val_loss = 0                                                 
    model.eval()                                                   
    with torch.no_grad():                                          
        for input, target in val_loader:                          
            output = model(input)                                   
            loss = criterion(output.flatten(), target.flatten())   
            val_loss += loss.item()                                
    val_loss /= len(val_loader.dataset)                            

    print("Epoch:{} Training Loss:{:.2f} Validation Loss:{:.2f}\n".format(
        epoch, train_loss, val_loss))
# Out:
#             2.1095e-02, -2.7192e-01],
#           ...,
#           [ 3.2226e-01,  4.5347e-01,  2.3209e-01,  ...,  2.4230e-01,
#             4.0212e-04, -3.1149e-01],
#           [ 2.0494e-01,  4.7580e-01,  3.3934e-01,  ...,  3.5961e-01,
#             1.3087e-01, -9.3340e-02],
#           [ 3.7936e-02,  2.0152e-01,  2.3050e-01,  ...,  2.5308e-01,
#             1.4328e-01,  1.5061e-01]],
#
#          [[-2.1071e-01, -5.8042e-01, -6.3509e-01,  ..., -6.3195e-01,
#            -4.8177e-01, -2.5134e-01],
#           [ 1.1850e-01, -8.6830e-02, -6.5349e-02,  ..., -6.2780e-02,
#             3.1555e-03,  2.0934e-01],
#           [-4.0732e-02, -3.3486e-01, -4.2540e-01,  ..., -3.9697e-01,
#            -4.1715e-01,  2.1538e-02],
#           ...,
#           [-4.3122e-02, -3.3719e-01, -4.4126e-01,  ..., -4.0688e-01,
#            -4.2962e-01, -2.9195e-03],
#           [-3.7700e-02, -3.3757e-01, -4.0492e-01,  ..., -3.9185e-01,
#            -4.3811e-01, -5.2229e-02],
#           [ 1.5817e-01,  1.7675e-01,  1.3084e-01,  ...,  1.4793e-01,
#             3.5827e-02,  2.3176e-01]],
#
#          [[-2.9279e-01, -2.8977e-01, -2.3502e-01,  ..., -2.2632e-01,
#            -1.4404e-01, -4.1346e-02],
#           [ 1.2141e-01,  3.4424e-01,  5.6414e-01,  ...,  5.7574e-01,
#             5.1880e-01,  5.1517e-01],
#           [ 1.9037e-01,  3.4883e-01,  4.6311e-01,  ...,  4.6097e-01,
#             4.0992e-01,  3.4709e-01],
#           ...,
#           [ 1.7367e-01,  3.4677e-01,  4.5711e-01,  ...,  4.7055e-01,
#             4.3653e-01,  3.4529e-01],
#           [ 1.3839e-01,  5.0133e-01,  7.2670e-01,  ...,  7.0894e-01,
#             6.9262e-01,  6.0408e-01],
#           [ 2.9829e-01,  4.6545e-01,  6.3132e-01,  ...,  6.0665e-01,
#             4.3631e-01,  4.8560e-01]]],
#
#
#         ...,
#
#
#         [[[ 4.8980e-02,  7.7017e-02,  2.2576e-01,  ...,  1.8180e-01,
#             9.5250e-02, -1.7432e-02],
#           [ 3.4354e-01,  4.6705e-01,  4.0954e-01,  ...,  3.4812e-01,
#             1.6073e-01, -4.5999e-03],
#           [ 3.8866e-02,  1.7535e-01,  7.8807e-02,  ...,  4.2902e-02,
#            -1.5378e-02,  1.7346e-03],
#           ...,
#           [ 5.6297e-02,  1.8868e-01,  9.1874e-02,  ...,  6.4042e-02,
#            -1.4811e-02, -6.3886e-03],
#           [-1.1356e-02,  1.0726e-01, -7.1765e-02,  ..., -8.9910e-02,
#            -2.0311e-01, -8.9407e-02],
#           [-6.9536e-03,  1.3344e-01, -7.2447e-02,  ..., -8.9347e-02,
#            -9.8941e-02, -7.7531e-02]],
#
#          [[-3.1938e-01, -2.3189e-01, -1.9736e-01,  ..., -1.5957e-01,
#            -1.1804e-01,  1.7881e-02],
#           [-1.8612e-01, -1.2482e-02, -7.4096e-03,  ...,  6.6940e-02,
#           [ 2.6999e-01,  9.1157e-02, -4.2737e-02,  ..., -7.3806e-02,
#            -1.6385e-01, -1.0555e-01]],
#
#          ...,
#
#          [[ 3.1414e-01,  3.9526e-01,  9.1291e-02,  ...,  7.0349e-02,
#            -4.6407e-02, -3.1587e-01],
#           [ 2.4609e-01,  3.2482e-01, -1.7432e-02,  ..., -3.5967e-02,
#            -2.4366e-01, -4.3086e-01],
#           [ 3.2568e-01,  4.5239e-01,  2.5550e-01,  ...,  2.7105e-01,
#             2.1095e-02, -2.7192e-01],
#           ...,
#           [ 3.2226e-01,  4.5347e-01,  2.3209e-01,  ...,  2.4230e-01,
#             4.0212e-04, -3.1149e-01],
#           [ 2.0494e-01,  4.7580e-01,  3.3934e-01,  ...,  3.5961e-01,
#             1.3087e-01, -9.3340e-02],
#           [ 3.7936e-02,  2.0152e-01,  2.3050e-01,  ...,  2.5308e-01,
#             1.4328e-01,  1.5061e-01]],
#
#          [[-2.1071e-01, -5.8042e-01, -6.3509e-01,  ..., -6.3195e-01,
#            -4.8177e-01, -2.5134e-01],
#           [ 1.1850e-01, -8.6830e-02, -6.5349e-02,  ..., -6.2780e-02,
#             3.1555e-03,  2.0934e-01],
#           [-4.0732e-02, -3.3486e-01, -4.2540e-01,  ..., -3.9697e-01,
#            -4.1715e-01,  2.1538e-02],
#           ...,
#           [-4.3122e-02, -3.3719e-01, -4.4126e-01,  ..., -4.0688e-01,
#            -4.2962e-01, -2.9195e-03],
#           [-3.7700e-02, -3.3757e-01, -4.0492e-01,  ..., -3.9185e-01,
#            -4.3811e-01, -5.2229e-02],
#           [ 1.5817e-01,  1.7675e-01,  1.3084e-01,  ...,  1.4793e-01,
#             3.5827e-02,  2.3176e-01]],
#
#          [[-2.9279e-01, -2.8977e-01, -2.3502e-01,  ..., -2.2632e-01,
#            -1.4404e-01, -4.1346e-02],
#           [ 1.2141e-01,  3.4424e-01,  5.6414e-01,  ...,  5.7574e-01,
#             5.1880e-01,  5.1517e-01],
#           [ 1.9037e-01,  3.4883e-01,  4.6311e-01,  ...,  4.6097e-01,
#             4.0992e-01,  3.4709e-01],
#           ...,
#           [ 1.7367e-01,  3.4677e-01,  4.5711e-01,  ...,  4.7055e-01,
#             4.3653e-01,  3.4529e-01],
#           [ 1.3839e-01,  5.0133e-01,  7.2670e-01,  ...,  7.0894e-01,
#             6.9262e-01,  6.0408e-01],
#           [ 2.9829e-01,  4.6545e-01,  6.3132e-01,  ...,  6.0665e-01,
#             4.3631e-01,  4.8560e-01]]],
#
#
#         [[[ 4.8980e-02,  7.7017e-02,  2.2576e-01,  ...,  1.8180e-01,
#             9.5250e-02, -1.7432e-02],
#           [ 3.4354e-01,  4.6705e-01,  4.0954e-01,  ...,  3.4812e-01,
#             1.6073e-01, -4.5999e-03],
#           [ 3.8866e-02,  1.7535e-01,  7.8807e-02,  ...,  4.2902e-02,
#            -1.5378e-02,  1.7346e-03],
#           ...,
#           [ 5.6297e-02,  1.8868e-01,  9.1874e-02,  ...,  6.4042e-02,
#            -1.4811e-02, -6.3886e-03],
#           [-1.1356e-02,  1.0726e-01, -7.1765e-02,  ..., -8.9910e-02,
#            -2.0311e-01, -8.9407e-02],
#           [-6.9536e-03,  1.3344e-01, -7.2447e-02,  ..., -8.9347e-02,
#            -9.8941e-02, -7.7531e-02]],
#
#          [[-3.1938e-01, -2.3189e-01, -1.9736e-01,  ..., -1.5957e-01,
#            -1.1804e-01,  1.7881e-02],
#           [-1.8612e-01, -1.2482e-02, -7.4096e-03,  ...,  6.6940e-02,
#             1.5637e-01,  2.8501e-01],
#           [-1.8822e-01, -3.1964e-01, -3.5543e-01,  ..., -2.8866e-01,
#            -2.4905e-01, -2.5216e-02],
#           ...,
#           [-2.1119e-01, -3.3186e-01, -3.6337e-01,  ..., -2.8579e-01,
#            -2.5112e-01,  3.2492e-03],
#           [-1.8594e-01, -4.7572e-01, -4.2582e-01,  ..., -3.7641e-01,
#            -2.9676e-01, -1.4351e-01],
#           [-3.5932e-02, -1.6175e-01, -9.3568e-02,  ..., -7.1920e-02,
#            -7.8175e-03,  1.7304e-01]],
#
#          [[ 9.6641e-02, -1.6605e-01, -9.0559e-02,  ..., -9.8686e-02,
#             2.5252e-02, -6.2932e-02],
#           [ 2.0148e-01, -7.8627e-02, -2.3729e-01,  ..., -2.5805e-01,
#            -1.8530e-01, -9.8222e-02],
#           [ 4.8232e-01,  1.0374e-01, -3.3591e-02,  ..., -6.6655e-02,
#            -1.6551e-01, -1.5942e-01],
#           ...,
#           [ 4.6687e-01,  8.5842e-02, -2.2433e-02,  ..., -4.8897e-02,
#            -1.4843e-01, -1.3500e-01],
#           [ 4.0267e-01, -8.1873e-02, -3.1289e-01,  ..., -3.4217e-01,
#            -5.4282e-01, -2.4692e-01],
#           [ 2.6999e-01,  9.1157e-02, -4.2737e-02,  ..., -7.3806e-02,
#            -1.6385e-01, -1.0555e-01]],
#
#          ...,
#
#          [[ 3.1414e-01,  3.9526e-01,  9.1291e-02,  ...,  7.0349e-02,
#            -4.6407e-02, -3.1587e-01],
#           [ 2.4609e-01,  3.2482e-01, -1.7432e-02,  ..., -3.5967e-02,
#            -2.4366e-01, -4.3086e-01],
#           [ 3.2568e-01,  4.5239e-01,  2.5550e-01,  ...,  2.7105e-01,
#             2.1095e-02, -2.7192e-01],
#           ...,
#           [ 3.2226e-01,  4.5347e-01,  2.3209e-01,  ...,  2.4230e-01,
#             4.0212e-04, -3.1149e-01],
#           [ 2.0494e-01,  4.7580e-01,  3.3934e-01,  ...,  3.5961e-01,
#             1.3087e-01, -9.3340e-02],
#           [ 3.7936e-02,  2.0152e-01,  2.3050e-01,  ...,  2.5308e-01,
#             1.4328e-01,  1.5061e-01]],
#
#          [[-2.1071e-01, -5.8042e-01, -6.3509e-01,  ..., -6.3195e-01,
#            -4.8177e-01, -2.5134e-01],
#           [ 1.1850e-01, -8.6830e-02, -6.5349e-02,  ..., -6.2780e-02,
#             3.1555e-03,  2.0934e-01],
#           [-4.0732e-02, -3.3486e-01, -4.2540e-01,  ..., -3.9697e-01,
#            -4.1715e-01,  2.1538e-02],
#           ...,
#           [-4.3122e-02, -3.3719e-01, -4.4126e-01,  ..., -4.0688e-01,
#            -4.2962e-01, -2.9195e-03],
#           [-3.7700e-02, -3.3757e-01, -4.0492e-01,  ..., -3.9185e-01,
#            -4.3811e-01, -5.2229e-02],
#           [ 1.5817e-01,  1.7675e-01,  1.3084e-01,  ...,  1.4793e-01,
#             3.5827e-02,  2.3176e-01]],
#
#          [[-2.9279e-01, -2.8977e-01, -2.3502e-01,  ..., -2.2632e-01,
#            -1.4404e-01, -4.1346e-02],
#           [ 1.2141e-01,  3.4424e-01,  5.6414e-01,  ...,  5.7574e-01,
#             5.1880e-01,  5.1517e-01],
#           [ 1.9037e-01,  3.4883e-01,  4.6311e-01,  ...,  4.6097e-01,
#             4.0992e-01,  3.4709e-01],
#           ...,
#           [ 1.7367e-01,  3.4677e-01,  4.5711e-01,  ...,  4.7055e-01,
#             4.3653e-01,  3.4529e-01],
#           [ 1.3839e-01,  5.0133e-01,  7.2670e-01,  ...,  7.0894e-01,
#             6.9262e-01,  6.0408e-01],
#           [ 2.9829e-01,  4.6545e-01,  6.3132e-01,  ...,  6.0665e-01,
#             4.3631e-01,  4.8560e-01]]]], device='cuda:0',
#        grad_fn=<ConvolutionBackward0>)
# tensor([[[[-0.0519, -0.0588,  0.0605,  ..., -0.0275, -0.0208, -0.0341],
#           [ 0.2407,  0.4013,  0.3529,  ...,  0.2285,  0.1320,  0.0978],
#           [ 0.0656,  0.2482,  0.1902,  ...,  0.1041,  0.0488,  0.1240],
#           ...,
#           [ 0.0845,  0.2674,  0.1960,  ...,  0.1265,  0.0462,  0.1231],
#           [ 0.0904,  0.2376,  0.0477,  ...,  0.0015, -0.1150,  0.0173],
#           [-0.0355,  0.0773, -0.0725,  ..., -0.0922, -0.0830,  0.0219]],
#
#          [[-0.1990, -0.1968, -0.2230,  ..., -0.1151, -0.1068, -0.1024],
#           [-0.2137, -0.1386, -0.2136,  ..., -0.0446,  0.0424,  0.0862],
#           [-0.1488, -0.2523, -0.3583,  ..., -0.2101, -0.1492, -0.0548],
#           ...,
#           [-0.2198, -0.2750, -0.4119,  ..., -0.2631, -0.1683, -0.0211],
#           [-0.1340, -0.2888, -0.3793,  ..., -0.2594, -0.2138, -0.0797],
#           [-0.0294,  0.0330,  0.0143,  ...,  0.0564,  0.0926,  0.2697]],
#
#          [[ 0.1097,  0.0508,  0.0007,  ...,  0.0200, -0.0158, -0.0184],
#           [ 0.0451, -0.0544, -0.2634,  ..., -0.2528, -0.2299,  0.0326],
#           [ 0.2745,  0.1413, -0.0695,  ..., -0.1104, -0.1744,  0.0069],
#           ...,
#           [ 0.2558,  0.1484, -0.0227,  ..., -0.0429, -0.1062,  0.0697],
#           [ 0.2237, -0.0846, -0.3257,  ..., -0.3741, -0.5172, -0.1171],
#           [ 0.1751,  0.1321,  0.0441,  ..., -0.0233, -0.0015,  0.0349]],
#
#          ...,
#
#          [[ 0.1261,  0.2406, -0.0025,  ..., -0.0253, -0.1120, -0.1740],
#           [-0.0137,  0.1045, -0.1835,  ..., -0.1954, -0.3417, -0.2808],
#           [ 0.1244,  0.2247,  0.0118,  ...,  0.0529, -0.2025, -0.2176],
#           ...,
#           [ 0.0841,  0.2389, -0.0409,  ...,  0.0029, -0.2124, -0.2706],
#           [ 0.1019,  0.3617,  0.1849,  ...,  0.2399,  0.0329, -0.0513],
#           [-0.1173,  0.0424, -0.0329,  ...,  0.0052, -0.0361,  0.0918]],
#
#          [[-0.1094, -0.3314, -0.3874,  ..., -0.3524, -0.2254, -0.1009],
#           [ 0.1185, -0.1342, -0.0934,  ..., -0.0837, -0.0042,  0.1110],
#           [ 0.0547, -0.1877, -0.1692,  ..., -0.1278, -0.0782,  0.1241],
#           ...,
#           [ 0.0823, -0.1697, -0.1851,  ..., -0.1379, -0.1185,  0.0699],
#           [ 0.0658, -0.2350, -0.1558,  ..., -0.1450, -0.1255,  0.0725],
#           [ 0.1743,  0.1366,  0.1681,  ...,  0.1599,  0.1087,  0.2364]],
#
#          [[-0.1845, -0.0814,  0.0026,  ...,  0.0376,  0.0410,  0.0015],
#           [ 0.0028,  0.1345,  0.3653,  ...,  0.4033,  0.2105,  0.2349],
#           [ 0.1250,  0.1346,  0.3433,  ...,  0.3660,  0.1845,  0.1322],
#           ...,
#           [ 0.0778,  0.1197,  0.2579,  ...,  0.2979,  0.1513,  0.0935],
#           [ 0.0234,  0.3179,  0.4969,  ...,  0.4687,  0.4078,  0.3693],
#           [ 0.2365,  0.1423,  0.2693,  ...,  0.2360,  0.0571,  0.0920]]],
#
#
#         [[[-0.0519, -0.0588,  0.0605,  ..., -0.0275, -0.0208, -0.0341],
#           [ 0.2407,  0.4013,  0.3529,  ...,  0.2285,  0.1320,  0.0978],
#           [ 0.0656,  0.2482,  0.1902,  ...,  0.1041,  0.0488,  0.1240],
#           ...,
#           [ 0.0845,  0.2674,  0.1960,  ...,  0.1265,  0.0462,  0.1231],
#           [ 0.0904,  0.2376,  0.0477,  ...,  0.0015, -0.1150,  0.0173],
#           [-0.0355,  0.0773, -0.0725,  ..., -0.0922, -0.0830,  0.0219]],
#
#          [[-0.1990, -0.1968, -0.2230,  ..., -0.1151, -0.1068, -0.1024],
#           [-0.2137, -0.1386, -0.2136,  ..., -0.0446,  0.0424,  0.0862],
#           [-0.1488, -0.2523, -0.3583,  ..., -0.2101, -0.1492, -0.0548],
#           ...,
#           [-0.2198, -0.2750, -0.4119,  ..., -0.2631, -0.1683, -0.0211],
#           [-0.1340, -0.2888, -0.3793,  ..., -0.2594, -0.2138, -0.0797],
#           [-0.0294,  0.0330,  0.0143,  ...,  0.0564,  0.0926,  0.2697]],
#
#          [[ 0.1097,  0.0508,  0.0007,  ...,  0.0200, -0.0158, -0.0184],
#           [ 0.0451, -0.0544, -0.2634,  ..., -0.2528, -0.2299,  0.0326],
#           [ 0.2745,  0.1413, -0.0695,  ..., -0.1104, -0.1744,  0.0069],
#           ...,
#           [ 0.2558,  0.1484, -0.0227,  ..., -0.0429, -0.1062,  0.0697],
#           [ 0.2237, -0.0846, -0.3257,  ..., -0.3741, -0.5172, -0.1171],
#           [ 0.1751,  0.1321,  0.0441,  ..., -0.0233, -0.0015,  0.0349]],
#
#          ...,
#
#          [[ 0.1261,  0.2406, -0.0025,  ..., -0.0253, -0.1120, -0.1740],
#           [-0.0137,  0.1045, -0.1835,  ..., -0.1954, -0.3417, -0.2808],
#           [ 0.1244,  0.2247,  0.0118,  ...,  0.0529, -0.2025, -0.2176],
#           ...,
#           [ 0.0841,  0.2389, -0.0409,  ...,  0.0029, -0.2124, -0.2706],
#           [ 0.1019,  0.3617,  0.1849,  ...,  0.2399,  0.0329, -0.0513],
#           [-0.1173,  0.0424, -0.0329,  ...,  0.0052, -0.0361,  0.0918]],
#
#          [[-0.1094, -0.3314, -0.3874,  ..., -0.3524, -0.2254, -0.1009],
#           [ 0.1185, -0.1342, -0.0934,  ..., -0.0837, -0.0042,  0.1110],
#           [ 0.0547, -0.1877, -0.1692,  ..., -0.1278, -0.0782,  0.1241],
#           ...,
#           [ 0.0823, -0.1697, -0.1851,  ..., -0.1379, -0.1185,  0.0699],
#           [ 0.0658, -0.2350, -0.1558,  ..., -0.1450, -0.1255,  0.0725],
#           [ 0.1743,  0.1366,  0.1681,  ...,  0.1599,  0.1087,  0.2364]],
#
#          [[-0.1845, -0.0814,  0.0026,  ...,  0.0376,  0.0410,  0.0015],
#           [ 0.0028,  0.1345,  0.3653,  ...,  0.4033,  0.2105,  0.2349],
#           [ 0.1250,  0.1346,  0.3433,  ...,  0.3660,  0.1845,  0.1322],
#           ...,
#           [ 0.0778,  0.1197,  0.2579,  ...,  0.2979,  0.1513,  0.0935],
#           [ 0.0234,  0.3179,  0.4969,  ...,  0.4687,  0.4078,  0.3693],
#           [ 0.2365,  0.1423,  0.2693,  ...,  0.2360,  0.0571,  0.0920]]],
#
#
#         [[[-0.0519, -0.0588,  0.0605,  ..., -0.0275, -0.0208, -0.0341],
#           [ 0.2407,  0.4013,  0.3529,  ...,  0.2285,  0.1320,  0.0978],
#           [ 0.0656,  0.2482,  0.1902,  ...,  0.1041,  0.0488,  0.1240],
#           ...,
#           [ 0.0845,  0.2674,  0.1960,  ...,  0.1265,  0.0462,  0.1231],
#           [ 0.0904,  0.2376,  0.0477,  ...,  0.0015, -0.1150,  0.0173],
#           [-0.0355,  0.0773, -0.0725,  ..., -0.0922, -0.0830,  0.0219]],
#
#          [[-0.1990, -0.1968, -0.2230,  ..., -0.1151, -0.1068, -0.1024],
#           [-0.2137, -0.1386, -0.2136,  ..., -0.0446,  0.0424,  0.0862],
#           [-0.1488, -0.2523, -0.3583,  ..., -0.2101, -0.1492, -0.0548],
#           ...,
#           [-0.2198, -0.2750, -0.4119,  ..., -0.2631, -0.1683, -0.0211],
#           [-0.1340, -0.2888, -0.3793,  ..., -0.2594, -0.2138, -0.0797],
#           [-0.0294,  0.0330,  0.0143,  ...,  0.0564,  0.0926,  0.2697]],
#
#          [[ 0.1097,  0.0508,  0.0007,  ...,  0.0200, -0.0158, -0.0184],
#           [ 0.0451, -0.0544, -0.2634,  ..., -0.2528, -0.2299,  0.0326],
#           [ 0.2745,  0.1413, -0.0695,  ..., -0.1104, -0.1744,  0.0069],
#           ...,
#           [ 0.2558,  0.1484, -0.0227,  ..., -0.0429, -0.1062,  0.0697],
#           [ 0.2237, -0.0846, -0.3257,  ..., -0.3741, -0.5172, -0.1171],
#           [ 0.1751,  0.1321,  0.0441,  ..., -0.0233, -0.0015,  0.0349]],
#
#          ...,
#
#          [[ 0.1261,  0.2406, -0.0025,  ..., -0.0253, -0.1120, -0.1740],
#           [-0.0137,  0.1045, -0.1835,  ..., -0.1954, -0.3417, -0.2808],
#           [ 0.1244,  0.2247,  0.0118,  ...,  0.0529, -0.2025, -0.2176],
#           ...,
#           [ 0.0841,  0.2389, -0.0409,  ...,  0.0029, -0.2124, -0.2706],
#           [ 0.1019,  0.3617,  0.1849,  ...,  0.2399,  0.0329, -0.0513],
#           [-0.1173,  0.0424, -0.0329,  ...,  0.0052, -0.0361,  0.0918]],
#
#          [[-0.1094, -0.3314, -0.3874,  ..., -0.3524, -0.2254, -0.1009],
#           [ 0.1185, -0.1342, -0.0934,  ..., -0.0837, -0.0042,  0.1110],
#           [ 0.0547, -0.1877, -0.1692,  ..., -0.1278, -0.0782,  0.1241],
#           ...,
#           [ 0.0823, -0.1697, -0.1851,  ..., -0.1379, -0.1185,  0.0699],
#           [ 0.0658, -0.2350, -0.1558,  ..., -0.1450, -0.1255,  0.0725],
#           [ 0.1743,  0.1366,  0.1681,  ...,  0.1599,  0.1087,  0.2364]],
#
#          [[-0.1845, -0.0814,  0.0026,  ...,  0.0376,  0.0410,  0.0015],
#           [ 0.0028,  0.1345,  0.3653,  ...,  0.4033,  0.2105,  0.2349],
#           [ 0.1250,  0.1346,  0.3433,  ...,  0.3660,  0.1845,  0.1322],
#           ...,
#           [ 0.0778,  0.1197,  0.2579,  ...,  0.2979,  0.1513,  0.0935],
#           [ 0.0234,  0.3179,  0.4969,  ...,  0.4687,  0.4078,  0.3693],
#           [ 0.2365,  0.1423,  0.2693,  ...,  0.2360,  0.0571,  0.0920]]],
#
#
#         ...,
#
#
#         [[[-0.0519, -0.0588,  0.0605,  ..., -0.0275, -0.0208, -0.0341],
#           [ 0.2407,  0.4013,  0.3529,  ...,  0.2285,  0.1320,  0.0978],
# ...
#
#
#         ...,
#
#
#         [[[-0.0374, -0.0387, -0.0388,  ..., -0.0388, -0.0388, -0.0370],
#           [-0.0367, -0.0368, -0.0366,  ..., -0.0366, -0.0365, -0.0350],
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           ...,
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           [-0.0368, -0.0368, -0.0365,  ..., -0.0366, -0.0365, -0.0348],
#           [-0.0359, -0.0380, -0.0377,  ..., -0.0377, -0.0377, -0.0348]],
#
#          [[ 0.0376,  0.0348,  0.0349,  ...,  0.0349,  0.0350,  0.0328],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0317,  0.0293],
#           [ 0.0342,  0.0316,  0.0316,  ...,  0.0316,  0.0317,  0.0293],
#           ...,
#           [ 0.0342,  0.0316,  0.0317,  ...,  0.0317,  0.0317,  0.0293],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0316,  0.0292],
#           [ 0.0338,  0.0324,  0.0324,  ...,  0.0324,  0.0323,  0.0302]],
#
#          [[ 0.0167,  0.0169,  0.0168,  ...,  0.0168,  0.0169,  0.0181],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           ...,
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0138,  0.0154,  0.0154,  ...,  0.0154,  0.0155,  0.0195],
#           [ 0.0120,  0.0116,  0.0117,  ...,  0.0117,  0.0116,  0.0160]],
#
#          ...,
#
#          [[ 0.0160,  0.0148,  0.0148,  ...,  0.0148,  0.0146,  0.0167],
#           [ 0.0210,  0.0223,  0.0223,  ...,  0.0223,  0.0221,  0.0216],
#           [ 0.0209,  0.0221,  0.0222,  ...,  0.0222,  0.0219,  0.0216],
#           ...,
#           [ 0.0209,  0.0221,  0.0223,  ...,  0.0223,  0.0219,  0.0216],
#           [ 0.0208,  0.0221,  0.0223,  ...,  0.0223,  0.0220,  0.0218],
#           [ 0.0215,  0.0214,  0.0215,  ...,  0.0215,  0.0213,  0.0201]],
#
#          [[ 0.0124,  0.0133,  0.0135,  ...,  0.0135,  0.0137,  0.0141],
#           [ 0.0111,  0.0115,  0.0115,  ...,  0.0115,  0.0117,  0.0136],
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0115,  0.0135],
#           ...,
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0114,  0.0135],
#           [ 0.0112,  0.0114,  0.0112,  ...,  0.0112,  0.0115,  0.0134],
#           [ 0.0122,  0.0125,  0.0123,  ...,  0.0123,  0.0123,  0.0147]],
#
#          [[-0.0253, -0.0261, -0.0259,  ..., -0.0259, -0.0261, -0.0301],
#           [-0.0247, -0.0246, -0.0245,  ..., -0.0245, -0.0246, -0.0301],
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           ...,
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           [-0.0247, -0.0247, -0.0247,  ..., -0.0247, -0.0248, -0.0304],
#           [-0.0253, -0.0265, -0.0265,  ..., -0.0265, -0.0265, -0.0306]]],
#
#
#         [[[-0.0374, -0.0387, -0.0388,  ..., -0.0388, -0.0388, -0.0370],
#           [-0.0367, -0.0368, -0.0366,  ..., -0.0366, -0.0365, -0.0350],
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           ...,
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           [-0.0368, -0.0368, -0.0365,  ..., -0.0366, -0.0365, -0.0348],
#           [-0.0359, -0.0380, -0.0377,  ..., -0.0377, -0.0377, -0.0348]],
#
#          [[ 0.0376,  0.0348,  0.0349,  ...,  0.0349,  0.0350,  0.0328],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0317,  0.0293],
#           [ 0.0342,  0.0316,  0.0316,  ...,  0.0316,  0.0317,  0.0293],
#           ...,
#           [ 0.0342,  0.0316,  0.0317,  ...,  0.0317,  0.0317,  0.0293],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0316,  0.0292],
#           [ 0.0338,  0.0324,  0.0324,  ...,  0.0324,  0.0323,  0.0302]],
#
#          [[ 0.0167,  0.0169,  0.0168,  ...,  0.0168,  0.0169,  0.0181],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           ...,
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0138,  0.0154,  0.0154,  ...,  0.0154,  0.0155,  0.0195],
#           [ 0.0120,  0.0116,  0.0117,  ...,  0.0117,  0.0116,  0.0160]],
#
#          ...,
#
#          [[ 0.0160,  0.0148,  0.0148,  ...,  0.0148,  0.0146,  0.0167],
#           [ 0.0210,  0.0223,  0.0223,  ...,  0.0223,  0.0221,  0.0216],
#           [ 0.0209,  0.0221,  0.0222,  ...,  0.0222,  0.0219,  0.0216],
#           ...,
#           [ 0.0209,  0.0221,  0.0223,  ...,  0.0223,  0.0219,  0.0216],
#           [ 0.0208,  0.0221,  0.0223,  ...,  0.0223,  0.0220,  0.0218],
#           [ 0.0215,  0.0214,  0.0215,  ...,  0.0215,  0.0213,  0.0201]],
#
#          [[ 0.0124,  0.0133,  0.0135,  ...,  0.0135,  0.0137,  0.0141],
#           [ 0.0111,  0.0115,  0.0115,  ...,  0.0115,  0.0117,  0.0136],
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0115,  0.0135],
#           ...,
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0114,  0.0135],
#           [ 0.0112,  0.0114,  0.0112,  ...,  0.0112,  0.0115,  0.0134],
#           [ 0.0122,  0.0125,  0.0123,  ...,  0.0123,  0.0123,  0.0147]],
#
#          [[-0.0253, -0.0261, -0.0259,  ..., -0.0259, -0.0261, -0.0301],
#           [-0.0247, -0.0246, -0.0245,  ..., -0.0245, -0.0246, -0.0301],
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           ...,
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           [-0.0247, -0.0247, -0.0247,  ..., -0.0247, -0.0248, -0.0304],
#           [-0.0253, -0.0265, -0.0265,  ..., -0.0265, -0.0265, -0.0306]]],
#
#
#         [[[-0.0374, -0.0387, -0.0388,  ..., -0.0388, -0.0388, -0.0370],
#           [-0.0367, -0.0368, -0.0366,  ..., -0.0366, -0.0365, -0.0350],
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           ...,
#           [-0.0365, -0.0365, -0.0363,  ..., -0.0363, -0.0363, -0.0348],
#           [-0.0368, -0.0368, -0.0365,  ..., -0.0366, -0.0365, -0.0348],
#           [-0.0359, -0.0380, -0.0377,  ..., -0.0377, -0.0377, -0.0348]],
#
#          [[ 0.0376,  0.0348,  0.0349,  ...,  0.0349,  0.0350,  0.0328],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0317,  0.0293],
#           [ 0.0342,  0.0316,  0.0316,  ...,  0.0316,  0.0317,  0.0293],
#           ...,
#           [ 0.0342,  0.0316,  0.0317,  ...,  0.0317,  0.0317,  0.0293],
#           [ 0.0341,  0.0315,  0.0315,  ...,  0.0315,  0.0316,  0.0292],
#           [ 0.0338,  0.0324,  0.0324,  ...,  0.0324,  0.0323,  0.0302]],
#
#          [[ 0.0167,  0.0169,  0.0168,  ...,  0.0168,  0.0169,  0.0181],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           ...,
#           [ 0.0139,  0.0153,  0.0152,  ...,  0.0152,  0.0153,  0.0193],
#           [ 0.0138,  0.0154,  0.0154,  ...,  0.0154,  0.0155,  0.0195],
#           [ 0.0120,  0.0116,  0.0117,  ...,  0.0117,  0.0116,  0.0160]],
#
#          ...,
#
#          [[ 0.0160,  0.0148,  0.0148,  ...,  0.0148,  0.0146,  0.0167],
#           [ 0.0210,  0.0223,  0.0223,  ...,  0.0223,  0.0221,  0.0216],
#           [ 0.0209,  0.0221,  0.0222,  ...,  0.0222,  0.0219,  0.0216],
#           ...,
#           [ 0.0209,  0.0221,  0.0223,  ...,  0.0223,  0.0219,  0.0216],
#           [ 0.0208,  0.0221,  0.0223,  ...,  0.0223,  0.0220,  0.0218],
#           [ 0.0215,  0.0214,  0.0215,  ...,  0.0215,  0.0213,  0.0201]],
#
#          [[ 0.0124,  0.0133,  0.0135,  ...,  0.0135,  0.0137,  0.0141],
#           [ 0.0111,  0.0115,  0.0115,  ...,  0.0115,  0.0117,  0.0136],
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0115,  0.0135],
#           ...,
#           [ 0.0110,  0.0113,  0.0112,  ...,  0.0112,  0.0114,  0.0135],
#           [ 0.0112,  0.0114,  0.0112,  ...,  0.0112,  0.0115,  0.0134],
#           [ 0.0122,  0.0125,  0.0123,  ...,  0.0123,  0.0123,  0.0147]],
#
#          [[-0.0253, -0.0261, -0.0259,  ..., -0.0259, -0.0261, -0.0301],
#           [-0.0247, -0.0246, -0.0245,  ..., -0.0245, -0.0246, -0.0301],
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           ...,
#           [-0.0246, -0.0245, -0.0244,  ..., -0.0244, -0.0246, -0.0302],
#           [-0.0247, -0.0247, -0.0247,  ..., -0.0247, -0.0248, -0.0304],
#           [-0.0253, -0.0265, -0.0265,  ..., -0.0265, -0.0265, -0.0306]]]],
#        device='cuda:0', grad_fn=<ConvolutionBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-de5cbd811fbb> in <module>()
#       8
#       9         print(input.shape)
# ---> 10         output = model(input)
#      11         loss = criterion(output.flatten(), target.flatten())
#      12         loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/My Drive/CS_231n_Project/ConvLSTM/Seq2Seq.py in forward(self, X)
#      46
#      47         # Forward propagation through all the layers
# ---> 48         output = self.sequential(X)
#      49
#      50         # Return only the last output frame
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/My Drive/CS_231n_Project/ConvLSTM/ConvLSTM.py in forward(self, X)
#      40         for time_step in range(seq_len):
#      41
# ---> 42             H, C = self.convLSTMcell(X[:,:,time_step], H, C)
#      43
#      44             output[:,:,time_step] = H
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/My Drive/CS_231n_Project/ConvLSTM/ConvLSTMCell.py in forward(self, X, H_prev, C_prev)
#      31         # Idea adapted from https://github.com/ndrplz/ConvLSTM_pytorch
#      32         conv_output = self.conv(torch.cat([X, H_prev], dim=1))
# ---> 33         print(conv_output)
#      34
#      35         # Idea adapted from https://github.com/ndrplz/ConvLSTM_pytorch
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __repr__(self)
#     303             return handle_torch_function(Tensor.__repr__, (self,), self)
#     304         # All strings are unicode in Python 3.
# --> 305         return torch._tensor_str._str(self)
#     306
#     307     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _str(self)
#     432 def _str(self):
#     433     with torch.no_grad():
# --> 434         return _str_intern(self)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _str_intern(inp)
#     407                     tensor_str = _tensor_str(self.to_dense(), indent)
#     408                 else:
# --> 409                     tensor_str = _tensor_str(self, indent)
#     410
#     411     if self.layout != torch.strided:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     263     else:
#     264         formatter = _Formatter(get_summarized_data(self) if summarize else self)
# --> 265         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     266
#     267 def _add_suffixes(tensor_str, suffixes, indent, force_newline):
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     221         slices = ([_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#     222                    for i in range(0, PRINT_OPTS.edgeitems)] +
# --> 223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#     225                    for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in <listcomp>(.0)
#     220     if summarize and self.size(0) > 2 * PRINT_OPTS.edgeitems:
#     221         slices = ([_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
# --> 222                    for i in range(0, PRINT_OPTS.edgeitems)] +
#     223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     221         slices = ([_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#     222                    for i in range(0, PRINT_OPTS.edgeitems)] +
# --> 223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#     225                    for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in <listcomp>(.0)
#     220     if summarize and self.size(0) > 2 * PRINT_OPTS.edgeitems:
#     221         slices = ([_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
# --> 222                    for i in range(0, PRINT_OPTS.edgeitems)] +
#     223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
# --> 225                    for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
#     226     else:
#     227         slices = [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in <listcomp>(.0)
#     223                   ['...'] +
#     224                   [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
# --> 225                    for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
#     226     else:
#     227         slices = [_tensor_str_with_formatter(self[i], indent + 1, summarize, formatter1, formatter2)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize what our model has learned so far

# %%
def collate_test(batch):

    # Last 10 frames are target
    target = np.array(batch)[:,10:]                     
    
    # Add channel dim, scale pixels between 0 and 1, send to GPU
    batch = torch.tensor(batch).unsqueeze(1)          
    batch = batch / 255.0                             
    batch = batch.to(device)                          
    return batch, target

# Test Data Loader
test_loader = DataLoader(test_data,shuffle=True, 
                         batch_size=3, collate_fn=collate_test)

# Get a batch
batch, target = next(iter(test_loader))

# Initialize output sequence
output = np.zeros(target.shape, dtype=np.uint8)

# Loop over timesteps
for timestep in range(target.shape[1]):
  input = batch[:,:,timestep:timestep+10]   
  output[:,timestep]=(model(input).squeeze(1).cpu()>0.5)*255.0

# %%
for tgt, out in zip(target, output):       # Loop over samples
    
    # Write target video as gif
    with io.BytesIO() as gif:
        imageio.mimsave(gif, tgt, "GIF", fps = 5)    
        target_gif = gif.getvalue()

    # Write output video as gif
    with io.BytesIO() as gif:
        imageio.mimsave(gif, out, "GIF", fps = 5)    
        output_gif = gif.getvalue()

    display(HBox([widgets.Image(value=target_gif), 
                  widgets.Image(value=output_gif)]))
